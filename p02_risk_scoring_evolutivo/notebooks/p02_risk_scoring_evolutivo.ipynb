# %% [markdown]
# # Predicción de riesgo dinámico (scoring evolutivo)
#
# Demo notebook scaffold (runs end-to-end).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r'data/p02_risk_scoring_evolutivo_data.csv')
df.head()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['t'], df['value'])
plt.title('Time series / Signal')
plt.xlabel('t')
plt.ylabel('value')
plt.tight_layout(); plt.savefig(r'img/p02_risk_scoring_evolutivo_plot.png', dpi=160)
plt.show()
