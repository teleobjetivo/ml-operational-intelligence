# %% [markdown]
# # Predicción de demanda con activación
#
# Demo notebook scaffold (runs end-to-end).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r'data/p04_demand_forecast_activation_data.csv')
df.head()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['t'], df['value'])
plt.title('Time series / Signal')
plt.xlabel('t')
plt.ylabel('value')
plt.tight_layout(); plt.savefig(r'img/p04_demand_forecast_activation_plot.png', dpi=160)
plt.show()
